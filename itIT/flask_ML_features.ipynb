# %%
    ## 각 피쳐들##
    HD_features(BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity, 
                                sleeptime,  Asthma, kidneydisease, age, diebtic)

        
    DI_features(heartdisease, BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity, 
                                sleeptime,  Asthma, kidneydisease, age)
                            
    KD_features(heartdisease, BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity, 
                                sleeptime,  Asthma, age, diebtic)
            
    ST_features(heartdisease, BMI, smoking, alchole, diffwalking, sex, physicalactivity, 
                            sleeptime,  Asthma, age, diebtic)
        
    AS_features(heartdisease, BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity, 
                            sleeptime, age, diebtic)
        

def features():
    HD_features = np.array([(BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity, 
                                    sleeptime,  Asthma, kidneydisease, age, diebtic)])

    DI_features = np.array([(heartdisease, BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity, 
                                    sleeptime,  Asthma, kidneydisease, age)])

    KD_features = np.array([(heartdisease, BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity, 
                                    sleeptime,  Asthma, age, diebtic)])

    ST_features = np.array([(heartdisease, BMI, smoking, alchole, diffwalking, sex, physicalactivity, 
                                sleeptime,  Asthma, age, diebtic)])

    AS_features = np.array([(heartdisease, BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity, 
                                sleeptime, age, diebtic)])
# ##### 심혈관질환 예측 ########
def HD_ML_predict(HD_model, HD_features):
    return HD_model.predict([[HD_features]])

# ##### 당뇨병 예측 ######## 
def DI_ML_predict(DI_model, DI_features):
    return DI_model.predict([[DI_features]])

# ##### 신장병 예측 ########
def KD_ML_predict(KD_model, KD_features):
    return KD_model.predict([[KD_features]])

# ##### 뇌졸증 예측 ########
def ST_ML_predict(ST_model, ST_features):
    return ST_model.predict([[ST_features]])

# ##### 천식 예측 ########
def AS_ML_predict(AS_model, AS_features):
    return AS_model.predict([[AS_features]])


{{% if HD_count == 1: <h2 style:'background:url({{url_for('static', filename='img')}})'>심장질환</span>%}}


def res_HD():
        input_method = 'POST'
        result_HD = HD_ML_predict(HD_model, HD_features)
def res_HD():
        input_method = 'POST'
        result_DI = DI_ML_predict(DI_model, DI_features)
def res_HD():
        input_method = 'POST'
        result_KD = KD_ML_predict(KD_model, KD_features)
def res_HD():
        input_method = 'POST'
        result_ST = ST_ML_predict(ST_model, ST_features)
def res_HD():
    input_method = 'POST'
    result_AS = AS_ML_predict(AS_model, AS_features)
        
        if result_HD == 1:
            HD_count = 1
        else:
            HD_count = 0

        if result_DI == 1:
            DI_count = 1
        else:
            DI_count = 0

        if result_KD == 1:
            KD_count = 1
        else:
            KD_count = 0

        if result_ST == 1:
            ST_count = 1
        else:
            ST_count = 0

        if result_AS == 1:
            AS_count = 1
        else:
            AS_count = 0

        return result_HD, result_DI, result_KD, result_ST, result_AS


        print(taller)
        print(weight)
        print(BMI)
        print(age)
        print(sex)
        print(sleeptime)
        print(smoking)
        print(alchole)
        print(physicalactivity)
        print(diffwalking)
        print(heartdisease)
        print(Asthma)
        print(kidneydisease)
        print(stroke)
        print(diebtic)
# Out:
#   Input In [1]
#     HD_features = np.array([(BMI, smoking, alchole, stroke, diffwalking, sex, physicalactivity,
#     ^
# IndentationError: expected an indented block
