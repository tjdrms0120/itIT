# %% [markdown]
# ## 라이브러리 패키지 호출

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, confusion_matrix, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn import preprocessing
from imblearn.over_sampling import SMOTE, RandomOverSampler, BorderlineSMOTE, ADASYN
from imblearn.combine import SMOTEENN, SMOTETomek 
from imblearn.under_sampling import NearMiss, RandomUnderSampler, CondensedNearestNeighbour, OneSidedSelection, TomekLinks, ClusterCentroids
from lightgbm import LGBMClassifier


import os
import sys
sys.path.append(os.pardir)
import graphviz
import mglearn
import xgboost as xgb
import seaborn as sns
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline

# %%
RandomUnderSampler : 랜덤하게 샘플링(무작위)
-> Tomek links : 두 범주 사이를 탐지하고 정리를 통해 부정확학 분류경계선 방지
CondensedNearestNeighbour : 이상 범주 전체와 다수 정상에서 무작위로 하나의 관측치를 선택하여 서브 데이터를 구성
-> I-NN알고리즘을 통해 원데이터를 분류 이상과 정상에서의 가까운 값을 바꾸어 준다. / 정상 분류된 다수 범주 관측치를 제거
OneSidedSelection : Tomek links + CNN  합친거

# %%
Cost swnsitive learning
Support vector data defcription(SVDD)

# %% [markdown]
# ### 모든 행,열 전부 다 출력
# - 주의할것 실행시키면 오래걸림

# %%
# pd.set_option('display.max_columns',None)
# pd.set_option('display.max_rows',None)

# %% [markdown]
# ### 데이터 호출
# - kaggle 데이터 셋 heart_2020_cleaned.csv

# %%
df = pd.read_csv('C:/Users/gjaischool/CHU/itIT/heart_2020_cleaned.csv')
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# ### 데이터 설명
# - HeartDisease 심장질환 :관상 동맥 심장 질환(CHD) 또는 심근 경색증(MI)이 있다고 보고한 적이 있는 응답자.
# - BMI: 체질량  지수
# - Smoking 흡연 : 일생동안 최소 100개피의 담배를 피웠는가?
# - AlcoholDrinking 알코올음주 : 성인남자는 14잔 이상, 여성은 7잔 이상 이면 과음자
# - Stroke 뇌졸증 : 뇌졸중이 있는가
# - PhysicalHealth 신체 건강 : 지난 30일 동안 신체건강이 좋지 않을 날이 며칠인가(0일~30일)
# - MentalHealth 정신 건강 : 지난 30일 동안 정신건강이 좋지 않을 날이 며칠인가(0일~30일)
# - DiffWalking 디프워킹 : 걷거나 계단을 오를때 힘든적이 있는가?
# - Sex 성별 : 남자(male), 여자(female)
# - AgeCategory 나이카테고리 : 14단계 연령 범주
# - (18 ~ 80 or older까지 각 14단계, 나이를 10대 단위로 4살차이로 구분)
# - Race 인종: 백인, 라틴계 미국인, 흑인,기타 인종,아시아인, 인디언인/알레스카인
# - Diabetic 당뇨병 : 당뇨병이 있습니까?
# - PhysicalActivity 신체 활동 : 30일 동안 정규업무 이외의 신체활동 또는 운동을 했다고 하는 성인
# - GenHealth	 젠 헬스 : 일반적인 건강 상태
# - SleepTime 수면시간 : 24시간 중 평균 몇시간의 수면을 취하십니까?
# - Asthma 천식 : 천식이 있습니까?
# - KidneyDisease 신장병 : 신장결석, 방광 감염, 요심금을 제외하고 신장질환이 있는가?
# - SkinCancer 피부암 : 피부암이 있는가?

# %% [markdown]
# ### 전체 데이터 정보

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %% [markdown]
# ### 전체 데이터 컴럼보기

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %% [markdown]
# ### 각 데이터 value_count보기

# %%
df['HeartDisease'].value_counts()
# Out:
# No     292422
# Yes     27373
# Name: HeartDisease, dtype: int64

# %%
df['BMI'].value_counts()
# Out:
# 26.63    3762
# 27.46    2767
# 27.44    2723
# 24.41    2696
# 27.12    2525
#          ...
# 59.85       1
# 50.59       1
# 92.53       1
# 62.95       1
# 46.56       1
# Name: BMI, Length: 3604, dtype: int64

# %%
df['Smoking'].value_counts()
# Out:
# No     187887
# Yes    131908
# Name: Smoking, dtype: int64

# %%
df['AlcoholDrinking'].value_counts()
# Out:
# No     298018
# Yes     21777
# Name: AlcoholDrinking, dtype: int64

# %%
df['Stroke'].value_counts()
# Out:
# No     307726
# Yes     12069
# Name: Stroke, dtype: int64

# %%
df['PhysicalHealth'].value_counts()
# Out:
# 0.0     226589
# 30.0     19509
# 2.0      14880
# 1.0      10489
# 3.0       8617
# 5.0       7606
# 10.0      5453
# 15.0      5012
# 7.0       4629
# 4.0       4468
# 20.0      3216
# 14.0      2893
# 6.0       1270
# 25.0      1164
# 8.0        924
# 21.0       626
# 12.0       605
# 28.0       446
# 29.0       204
# 9.0        180
# 18.0       167
# 16.0       135
# 27.0       124
# 17.0       110
# 13.0        91
# 22.0        89
# 11.0        85
# 24.0        67
# 26.0        66
# 23.0        46
# 19.0        35
# Name: PhysicalHealth, dtype: int64

# %%
df['MentalHealth'].value_counts()
# Out:
# 0.0     205401
# 30.0     17373
# 2.0      16495
# 5.0      14149
# 10.0     10513
# 3.0      10466
# 15.0      9896
# 1.0       9291
# 7.0       5528
# 20.0      5431
# 4.0       5379
# 14.0      2048
# 25.0      1954
# 6.0       1510
# 8.0       1094
# 12.0       757
# 28.0       515
# 21.0       352
# 29.0       317
# 18.0       211
# 9.0        203
# 16.0       152
# 17.0       128
# 27.0       126
# 13.0       110
# 22.0        98
# 11.0        83
# 23.0        68
# 24.0        67
# 26.0        59
# 19.0        21
# Name: MentalHealth, dtype: int64

# %%
df['DiffWalking'].value_counts()
# Out:
# No     275385
# Yes     44410
# Name: DiffWalking, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Female    167805
# Male      151990
# Name: Sex, dtype: int64

# %%
df['AgeCategory'].value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %%
df['Race'].value_counts()
# Out:
# White                             245212
# Hispanic                           27446
# Black                              22939
# Other                              10928
# Asian                               8068
# American Indian/Alaskan Native      5202
# Name: Race, dtype: int64

# %%
df['Diabetic'].value_counts()
# Out:
# No                         269653
# Yes                         40802
# No, borderline diabetes      6781
# Yes (during pregnancy)       2559
# Name: Diabetic, dtype: int64

# %% [markdown]
# ### borderline diabtes : 경계성 당뇨 : 당뇨 전 단계
# ### during pregnancy : 임신 중

# %%
df['PhysicalActivity'].value_counts()
# Out:
# Yes    247957
# No      71838
# Name: PhysicalActivity, dtype: int64

# %%
df['GenHealth'].value_counts()
# Out:
# Very good    113858
# Good          93129
# Excellent     66842
# Fair          34677
# Poor          11289
# Name: GenHealth, dtype: int64

# %%
df['SleepTime'].value_counts()
# Out:
# 7.0     97751
# 8.0     97602
# 6.0     66721
# 5.0     19184
# 9.0     16041
# 10.0     7796
# 4.0      7750
# 12.0     2205
# 3.0      1992
# 2.0       788
# 1.0       551
# 11.0      415
# 14.0      243
# 16.0      236
# 15.0      189
# 18.0      102
# 13.0       97
# 20.0       64
# 24.0       30
# 17.0       21
# 22.0        9
# 19.0        3
# 23.0        3
# 21.0        2
# Name: SleepTime, dtype: int64

# %%
df['Asthma'].value_counts()
# Out:
# No     276923
# Yes     42872
# Name: Asthma, dtype: int64

# %%
df['KidneyDisease'].value_counts()
# Out:
# No     308016
# Yes     11779
# Name: KidneyDisease, dtype: int64

# %%
df['SkinCancer'].value_counts()
# Out:
# No     289976
# Yes     29819
# Name: SkinCancer, dtype: int64

# %% [markdown]
# ### 범주형값을 수치값으로 변환(AgeCategory, Diabetic)
# - OrfinalEncoder으로 라베링 실시
# - AgeCategory, Diabetic값 OrdinalEncoder로 변환

# %%
one_dr_encoder = OrdinalEncoder()

# %%
age_df = df[['AgeCategory']]
age_df
# Out:
#         AgeCategory
# 0             55-59
# 1       80 or older
# 2             65-69
# 3             75-79
# 4             40-44
# ...             ...
# 319790        60-64
# 319791        35-39
# 319792        45-49
# 319793        25-29
# 319794  80 or older
#
# [319795 rows x 1 columns]

# %%
df_age = one_dr_encoder.fit_transform(age_df)
o_e_df= pd.DataFrame(df_age, columns=['Age'])
o_e_df.value_counts()
# Out:
# Age
# 9.0     34151
# 8.0     33686
# 10.0    31065
# 7.0     29757
# 6.0     25382
# 12.0    24153
# 5.0     21791
# 11.0    21482
# 0.0     21064
# 4.0     21006
# 3.0     20550
# 2.0     18753
# 1.0     16955
# dtype: int64

# %%
df_diab= df[['Diabetic']]
df_diab.value_counts()
# Out:
# Diabetic
# No                         269653
# Yes                         40802
# No, borderline diabetes      6781
# Yes (during pregnancy)       2559
# dtype: int64

# %%
o_e_di = one_dr_encoder.fit_transform(df_diab)
di = pd.DataFrame(o_e_di, columns = ['Diabetic'])
di.value_counts()
# Out:
# Diabetic
# 0.0         269653
# 2.0          40802
# 1.0           6781
# 3.0           2559
# dtype: int64

# %%
di = di.replace({'Diabetic': 1}, 0)
di = di.replace({'Diabetic': 2}, 1)
di = di.replace({'Diabetic': 3}, 1)
di
# Out:
#         Diabetic
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            0.0
# ...          ...
# 319790       1.0
# 319791       0.0
# 319792       0.0
# 319793       0.0
# 319794       0.0
#
# [319795 rows x 1 columns]

# %% [markdown]
# ### Diabetic 값 제거

# %%
X_df = df.drop(columns=['Diabetic'],axis=1)
X_df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race  \
# ...

# %% [markdown]
# ### 변환했던 값 concat으로 합치기
# - o_e_df : AgeCategory
# - di : Diabetic

# %%
X_df = pd.concat([X_df, o_e_df, di], axis=1, join='inner') 
X_df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race  \
# ...

# %% [markdown]
# ### 나이구간을 구분하여 컬럼 지정

# %%
bins = [-1,1,3,5,7,13]
group_name = [1,2,3,4,5]
categorise = pd.cut(X_df['Age'],bins,labels=group_name)
X_df['Age']=categorise
X_df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race  \
# ...

# %%
X_df['Age'].value_counts()
# Out:
# 5    144537
# 4     55139
# 3     42797
# 2     39303
# 1     38019
# Name: Age, dtype: int64

# %% [markdown]
# ### Age타입 변경 : int64

# %%
X1_df = X_df.astype({'Age':'int64'})

# %%
X1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  PhysicalActivity  319795 non-null  object
#  12  GenHealth         319795 non-null  object
#  13  SleepTime         319795 non-null  float64
#  14  Asthma            319795 non-null  object
# ...

# %%
X1_df_1 = X1_df.drop(columns=['AgeCategory'],axis=1)
X1_df_1
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex      Race PhysicalActivity  \
# ...

# %% [markdown]
# ### 불필요한 데이터 drop ('AgeCategory','PhysicalHealth','MentalHealth','Race','GenHealth')

# %%
X1_df_1 = X1_df_1.drop(columns=['DiffWalking','Asthma','KidneyDisease',
                              'Race','GenHealth','SkinCancer'],axis=1)
X1_df_1
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth     Sex PhysicalActivity  SleepTime  Age  Diabetic
# ...

# %%
X1_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   Sex               319795 non-null  object
#  8   PhysicalActivity  319795 non-null  object
#  9   SleepTime         319795 non-null  float64
#  10  Age               319795 non-null  int64
#  11  Diabetic          319795 non-null  float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 29.3+ MB

# %%
X1_df_1['Age'].value_counts()
# Out:
# 5    144537
# 4     55139
# 3     42797
# 2     39303
# 1     38019
# Name: Age, dtype: int64

# %% [markdown]
# ### 인코딩 작업
# - 축약 if문 사용

# %%
X1_df_1['HeartDisease'] = [1 if each == 'Yes' else 0 for each in X1_df_1['HeartDisease']]

# %%
X1_df_1['Smoking'] = [1 if each == 'Yes' else 0 for each in X1_df_1['Smoking']]

# %%
X1_df_1['AlcoholDrinking'] = [1 if each == 'Yes' else 0 for each in X1_df_1['AlcoholDrinking']]

# %%
X1_df_1['Stroke'] = [1 if each == 'Yes' else 0 for each in X1_df_1['Stroke']]

# %%
X1_df_1['Sex'] = [1 if each == 'Male' else 0 for each in X1_df_1['Sex']]

# %%
X1_df_1['PhysicalActivity'] = [1 if each == 'Yes' else 0 for each in X1_df_1['PhysicalActivity']]

# %%
# X1_df_1['DiffWalking'] = [1 if each == 'Yes' else 0 for each in X1_df_1['DiffWalking']]

# %%
# X1_df_1['Asthma'] = [1 if each == 'Yes' else 0 for each in X1_df_1['Asthma']]

# %%
# X1_df_1['KidneyDisease'] = [1 if each == 'Yes' else 0 for each in X1_df_1['KidneyDisease']]

# %%
# X1_df_1['SkinCancer'] = [1 if each == 'Yes' else 0 for each in X1_df_1['SkinCancer']]

# %%
X1_df_1
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0             3.0
# 1                  0  20.34        0                0       1             0.0
# 2                  0  26.58        1                0       0            20.0
# 3                  0  24.21        0                0       0             0.0
# 4                  0  23.71        0                0       0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0             7.0
# 319791             0  29.84        1                0       0             0.0
# 319792             0  24.24        0                0       0             0.0
# 319793             0  32.81        0                0       0             0.0
# 319794             0  46.56        0                0       0             0.0
#
# ...

# %% [markdown]
# ### 지금까지 데이터 상관계수 보기

# %%
corrmat = X1_df_1.corr()
top_corr_fea = corrmat.index[abs(corrmat['HeartDisease'])>=0.3]
top_corr_fea
# Out:
# Index(['HeartDisease'], dtype='object')

# %%
plt.figure(figsize=(23,23))
g = sns.heatmap(X1_df_1.corr(), annot=True, cmap='RdYlGn')

# %% [markdown]
# ### Y타겟(HeartDisease) 설정 및 제거

# %%
y_target = X1_df_1['HeartDisease']
y_target.value_counts()
# Out:
# 0    292422
# 1     27373
# Name: HeartDisease, dtype: int64

# %%
X1_df_1 = X1_df_1.drop(columns=['HeartDisease'],axis=1)
X1_df_1
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0             3.0          30.0
# 1       20.34        0                0       1             0.0           0.0
# 2       26.58        1                0       0            20.0          30.0
# 3       24.21        0                0       0             0.0           0.0
# 4       23.71        0                0       0            28.0           0.0
# ...       ...      ...              ...     ...             ...           ...
# 319790  27.41        1                0       0             7.0           0.0
# 319791  29.84        1                0       0             0.0           0.0
# 319792  24.24        0                0       0             0.0           0.0
# 319793  32.81        0                0       0             0.0           0.0
# 319794  46.56        0                0       0             0.0           0.0
#
# ...

# %% [markdown]
# ### 구간값을 실수값으로 구분하여 레이블 저장 및 타입 변경 : 원래 -object / 변경타입 - int
# - 0 ~ 18.50 : 저체중 / groupnames = 1
# - 18.50 ~ 24.99 : 정상 / groupnames = 2
# - 25.00 ~ 29.99 : 과체중 / groupnames = 3
# - 30.00 ~ 34.99 : 1단계 비만 / groupnames = 4
# - 35.00 ~ 39.99 : 2단계 비만 / groupnames = 5
# - 40 ~ : 고도비만 / groupnames = 6

# %%
bins  = [0,18.50,24.99,29.99,34.99,39.99,99]
group_names = [1,2,3,4,5,6]   # bin a < 구간 <= b
categorise = pd.cut(X1_df_1['BMI'],bins,labels=group_names)
X1_df_1["BMI"]= categorise
X1_df_1['BMI'].value_counts()   # 1: 저체중 2:정상 3:과체중 4: 1단계비만 5: 2단계 비만 6: 고도비만
# Out:
# 3    114512
# 2     97327
# 4     61345
# 5     25112
# 6     16385
# 1      5114
# Name: BMI, dtype: int64

# %%
X1_df_1 = X1_df_1.astype({'BMI':'float64'})

# %%
X1_df_1
# Out:
#         BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       1.0        1                0       0             3.0          30.0
# 1       2.0        0                0       1             0.0           0.0
# 2       3.0        1                0       0            20.0          30.0
# 3       2.0        0                0       0             0.0           0.0
# 4       2.0        0                0       0            28.0           0.0
# ...     ...      ...              ...     ...             ...           ...
# 319790  3.0        1                0       0             7.0           0.0
# 319791  3.0        1                0       0             0.0           0.0
# 319792  2.0        0                0       0             0.0           0.0
# 319793  4.0        0                0       0             0.0           0.0
# 319794  6.0        0                0       0             0.0           0.0
#
#         Sex  PhysicalActivity  SleepTime  Age  Diabetic
# ...

# %% [markdown]
# ### 최종 데이터 상관계수 확인 및 나머지 값 타입 변경
# - 최종데이터 : train_df

# %%
train_df = X1_df_1
train_df
# Out:
#         BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       1.0        1                0       0             3.0          30.0
# 1       2.0        0                0       1             0.0           0.0
# 2       3.0        1                0       0            20.0          30.0
# 3       2.0        0                0       0             0.0           0.0
# 4       2.0        0                0       0            28.0           0.0
# ...     ...      ...              ...     ...             ...           ...
# 319790  3.0        1                0       0             7.0           0.0
# 319791  3.0        1                0       0             0.0           0.0
# 319792  2.0        0                0       0             0.0           0.0
# 319793  4.0        0                0       0             0.0           0.0
# 319794  6.0        0                0       0             0.0           0.0
#
#         Sex  PhysicalActivity  SleepTime  Age  Diabetic
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   BMI               319795 non-null  float64
#  1   Smoking           319795 non-null  int64
#  2   AlcoholDrinking   319795 non-null  int64
#  3   Stroke            319795 non-null  int64
#  4   PhysicalHealth    319795 non-null  float64
#  5   MentalHealth      319795 non-null  float64
#  6   Sex               319795 non-null  int64
#  7   PhysicalActivity  319795 non-null  int64
#  8   SleepTime         319795 non-null  float64
#  9   Age               319795 non-null  int64
#  10  Diabetic          319795 non-null  float64
# dtypes: float64(5), int64(6)
# memory usage: 26.8 MB

# %%
train_df = train_df.astype({'SleepTime':'float64'})
train_df = train_df.astype({'Diabetic':'float64'})

# %%
train_df
# Out:
#         BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       1.0        1                0       0             3.0          30.0
# 1       2.0        0                0       1             0.0           0.0
# 2       3.0        1                0       0            20.0          30.0
# 3       2.0        0                0       0             0.0           0.0
# 4       2.0        0                0       0            28.0           0.0
# ...     ...      ...              ...     ...             ...           ...
# 319790  3.0        1                0       0             7.0           0.0
# 319791  3.0        1                0       0             0.0           0.0
# 319792  2.0        0                0       0             0.0           0.0
# 319793  4.0        0                0       0             0.0           0.0
# 319794  6.0        0                0       0             0.0           0.0
#
#         Sex  PhysicalActivity  SleepTime  Age  Diabetic
# ...

# %%
plt.figure(figsize=(23,23))
g = sns.heatmap(train_df.corr(), annot=True, cmap='RdYlGn')

# %% [markdown]
# ### 학습 및 정확도 확인, 변수중요도 확인

# %%
X = train_df

# %%
y = y_target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
# X_train_valid, X_test, y_train_valid, y_test = train_test_split(X, y, test_size=0.05, stratify=y)
# X_train, X_train_valid, y_train, y_train_valid = train_test_split(X_train_valid, y_train_valid, test_size=0.05, stratify=y_train_valid)

# %%
# xgbr_all = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, objective='reg:squarederror', radom_state=2021)
# xgbr_all.fit(X_train, y_train)
# pred = xgbr_all.predict(X_train_valid)

# rmse = np.sqrt(mean_squared_error(y_train_valid, pred))

# fig, ax = plt.subplots(figsize=(10,10))
# plot_importance(xgbr_all, ax=ax)

# %% [markdown]
# ### Under sampling

# %%
nermiss = NearMiss()
X, y = nermiss.fit_resample(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
rus = RandomUnderSampler()
X,y = rus.fit_resample(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
tomeklinks = TomekLinks()
X, y = tomeklinks.fit_resample(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
oss = OneSidedSelection()
X, y = oss.fit_resample(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
cc = ClusterCentroids()
X, y = cc.fit_resample(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
cnn = CondensedNearestNeighbour()
X, y = cnn.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %% [markdown]
# ### Over sample

# %%
smote = SMOTE()

# %%
X, y = smote.fit_resample(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
smoenn = SMOTEENN()
X, y = smoenn.fit_resample(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.05, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((336984, 11), (17737, 11), (336984,), (17737,))

# %% [markdown]
# ### RandomForestRegressor

# %%
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)
rf_model.score(X_train, y_train)
# rf_model.score(y_test, y_pred)
# accuracy_score(rf_model, y_test)

# %% [markdown]
# ### LogisticRegression

# %%
lr_model = LogisticRegression(max_iter=100000)
lr_model.fit(X_train, y_train)
pred_lr = lr_model.predict(X_test)
accuracy_score(pred_lr, y_test)

# %% [markdown]
# ### DecisiontreeClassifier

# %%
# max_depth=5,min_samples_split=2
dt_model = DecisionTreeClassifier()
parameters = {'max_depth' : [5,10,15,20],
              'min_samples_split':[2,4,6,8]
              }
grid_dt_model = GridSearchCV(dt_model, param_grid=parameters, cv=3, refit=True)
grid_dt_model.fit(X_train, y_train)

scores_df = pd.DataFrame(grid_dt_model.cv_results_)
print('GridSearchCV 최적 파라미터:', grid_dt_model.best_params_)
print('GridSearchCV 최고 정확도: {0:.4f}'.format(grid_dt_model.best_score_))
# dt_model.fit(X_train, y_train)
# pred_dt = dt_model.predict(X_test)
# accuracy_score(pred_dt, y_test)

# %% [markdown]
# ### KNN

# %%
knn_model = KNeighborsClassifier(n_neighbors=12, metric='euclidean', weights='distance')
knn_model.fit(X_train, y_train)
pred_knn = knn_model.predict(X_test)
accuracy_score(pred_knn, y_test)

# %% [markdown]
# ### GridSearchCV
# - LogisticRegression, 교차검증하여 파라미터 값 설정
# - RandomForestClassifier, 교차검증하여 파라미터 값 설정

# %%
lr_model_1 = LogisticRegression()

lr_grid = {'solver':['liblinear', 'lbfgs'],
    'penalty':['l1', 'l2'],
    'C':[0.01, 0.1, 1, 5, 10 ]
}
lr_res = GridSearchCV(estimator = lr_model_1,
                     param_grid=lr_grid,
                     n_jobs= -1, cv=5)

lr_res.fit(X_train, y_train)
lr_res.score(X_train, y_train), lr_res.score(X_test, y_test), lr_res.best_params_

# %%
# rf_model = RandomForestClassifier(n_estimators=40, max_depth=10, max_features='sqrt',min_samples_split=3)

# # rf_grid = {
# #     'n_estimators': [20,40,60,80],
# #     'max_depth': [5,10,15,20],
# #     'min_samples_split': [0.5, 1, 1.5, 3],
# #     'max_features': ['auto', 'sqrt'],
# # }
# # rf_res = GridSearchCV(estimator=rf_model,
# #                      param_grid=rf_grid,
# #                      n_jobs= -1,
# #                      cv=5)
# rf_model.fit(X_train,y_train)
# rf_model.score(X_train, y_train),rf_model.score(X_test, y_test)
# pred =rf_model.predict(X_test)
# get_clf_eval(y_test, pred)

# %%
lr_model = LogisticRegression(C=0.01, penalty='l1', solver='liblinear')
lr_model.fit(X_train, y_train)
pred = lr_model.predict(X_test)
# 오차행렬
print(confusion_matrix(y_test, pred)*100)
# 정확도
print(accuracy_score(y_test, pred)*100)
# 정밀도
print(precision_score(y_test, pred)*100)
# 재현율
print(recall_score(y_test, pred)*100)
print(f1_score(y_test, pred)*100)
print(r2_score(y_test, pred)*100)
# Out:
# [[1019400  111400]
#  [ 190000  452900]]
# 83.00727293228843
# 80.25872762714869
# 70.44641468346555
# 75.03313452617628
# 26.464984478769303

# %%
dt_model = DecisionTreeClassifier(max_depth=5, min_samples_split=2)
dt_model.fit(X_train, y_train)
pred = lr_model.predict(X_test)
# 오차행렬
print(confusion_matrix(y_test, pred)*100)
# 정확도
print(accuracy_score(y_test, pred)*100)
# 정밀도
print(precision_score(y_test, pred)*100)
# 재현율
print(recall_score(y_test, pred)*100)
print(f1_score(y_test, pred)*100)

# %%
def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
#     roc_auc = roc_auc(y_test, pred_proba)
    print('오차행렬')
    print(confusion)
    print('정확도:{0:.4f},정밀도:{1:.4f},재현율:{2:.4f},F1{3:.4f}'.format(accuracy, precision, recall, f1))

# %%
def get_model_train_eval(model, ftr_train = None, ftr_test=None, tgt_train=None, tgt_test=None):
    model.fit(ftr_train, tgt_train)
    pred = model.predict(ftr_test)
    pred_proba = model.predict_proba(ftr_test)[:, 1]
    get_clf_eval(tgt_test, pred, pred_proba)

# %%
lgbm_clf = LGBMClassifier(n_estimators=1000, num_leaves=64, n_jobs=-1, boost_from_average=True)
get_model_train_eval(lgbm_clf, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)

# %%
xgb_model = XGBClassifier(base_score = 0.5,
                          n_estimators = 300,
                          learning_rate = 0.1,
                          max_depth = 50,
                          min_child_weight = 1,
                          reg_lambda=500,
                          n_jobs=-1,
                          subsample=1,
                          colsample_bytree=1
)
get_model_train_eval(xgb_model, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)

# %%
xgb_model.score(X_train, y_train), xgb_model.score(X_test, y_test)

# %%
base_score = 0.5,
                          n_estimators = 300,
                          learning_rate = 0.1,
                          max_depth = 50,
                          min_child_weight = 1,
                          reg_lambda=500,
                          n_jobs=-1,
                          subsample=1,
                          colsample_bytree=1

# %%
def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
#     roc_auc = roc_auc(y_test, pred_proba)
    print('오차행렬')
    print(confusion)
    print('정확도:{0:.4f},정밀도:{1:.4f},재현율:{2:.4f},F1{3:.4f}'.format(accuracy, precision, recall, f1))

# %%
# def get_model_train_eval(model, ftr_train = None, ftr_test=None, tgt_train=None, tgt_test=None):
#     model.fit(ftr_train, tgt_train)
#     pred = model.predict(ftr_test)
# #     pred_proba = model.mean_squared_error(ftr_test)[:, 1]
#     get_clf_eval(tgt_test, pred)

# %%
xgb_model = XGBRegressor()
xgb_model.fit(X_train, y_train)
pred = xgb_model.predict(X_test)
get_clf_eval(xgb_model, ftr_train=X_train, ftr_test=X_test, tgt_train=y_train, tgt_test=y_test)

# %%
print(mean_squared_error(y_test, pred))
# Out:
# 0.06054534963176419

# %%
xgb_model = XGBClassifier()

xgb_model_grid = {
    'n_estimators' : [100, 200, 400, 600],
    'learning_rate' : [0.01, 0.05, 0.1, 1],
    'max_depth' : [4, 6, 8, 10],
    'min_child_weight' :[2,4,6,8],
    'scale_pos_weight' :[0.01, 0.05, 0.1, 1],
    'reg_lambda' :[4,6,7,10],
    'subsample' : [0.5,0.7, 0.8,1],
    'colsample_bytree' : [0.5,0.7, 0.8,1],  
}
lr_res = GridSearchCV(estimator = xgb_model,
                     param_grid=xgb_model_grid,
                     n_jobs= -1, cv=5)

lr_res.fit(X_train, y_train)
lr_res.score(X_train, y_train), lr_res.score(X_test, y_test), lr_res.best_params_
